# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedaRaihaAliKazmi1/git_tutorials/blob/main/raiha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-560450af-7306-4530-b604-5a08206be418" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-560450af-7306-4530-b604-5a08206be418">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: StressLevelDataset.csv
#   inflating: Stress_Dataset.csv

# %%
# !ls
# Out:
# archive.zip  sample_data  Stress_Dataset.csv  StressLevelDataset.csv

# %%
import pandas as pd
df=pd.read_csv('Stress_Dataset.csv')
print(df.head())
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=843, step=1)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Have you recently experienced stress in your life?',
#        'Have you noticed a rapid heartbeat or palpitations?',
#        'Have you been dealing with anxiety or tension recently?',
#        'Do you face any sleep problems or difficulties falling asleep?',
#        'Have you been dealing with anxiety or tension recently?.1',
#        'Have you been getting headaches more often than usual?',
#        'Do you get irritated easily?',
#        'Do you have trouble concentrating on your academic tasks?',
#        'Have you been feeling sadness or low mood?',
#        'Have you been experiencing any illness or health issues?',
#        'Do you often feel lonely or isolated?',
#        'Do you feel overwhelmed with your academic workload?',
#        'Are you in competition with your peers, and does it affect you?',
#        'Do you find that your relationship often causes you stress?',
# ...

# %%
df.describe()
# Out:
#            Gender         Age  \
# count  843.000000  843.000000
# mean     0.349941   20.071174
# std      0.477234    5.429502
# min      0.000000   14.000000
# 25%      0.000000   19.000000
# 50%      0.000000   19.000000
# 75%      1.000000   20.000000
# max      1.000000  100.000000
#
#        Have you recently experienced stress in your life?  \
# count                                         843.000000
# mean                                            2.997628
# std                                             1.134639
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you noticed a rapid heartbeat or palpitations?  \
# count                                         843.000000
# ...

# %%
df[4:6]
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 4       0   20                                                  3
# 5       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 4                                                  3
# 5                                                  4
#
#    Have you been dealing with anxiety or tension recently?  \
# 4                                                  3
# 5                                                  3
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 4                                                  2
# 5                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 4                                                  2
# 5                                                  3
#
#    Have you been getting headaches more often than usual?  \
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.index.array
# Out:
# <NumpyExtensionArray>
# [  np.int64(0),   np.int64(1),   np.int64(2),   np.int64(3),   np.int64(4),
#    np.int64(5),   np.int64(6),   np.int64(7),   np.int64(8),   np.int64(9),
#  ...
#  np.int64(833), np.int64(834), np.int64(835), np.int64(836), np.int64(837),
#  np.int64(838), np.int64(839), np.int64(840), np.int64(841), np.int64(842)]
# Length: 843, dtype: int64

# %%
df.to_numpy()
# Out:
# array([[0, 20, 3, ..., 1, 2,
#         'Eustress (Positive Stress) - Stress that motivates and enhances performance.'],
#        [0, 20, 2, ..., 4, 2,
#         'Eustress (Positive Stress) - Stress that motivates and enhances performance.'],
#        [0, 20, 5, ..., 2, 1,
#         'Eustress (Positive Stress) - Stress that motivates and enhances performance.'],
#        ...,
#        [1, 19, 4, ..., 5, 3,
#         'Eustress (Positive Stress) - Stress that motivates and enhances performance.'],
#        [0, 20, 5, ..., 5, 1,
#         'Eustress (Positive Stress) - Stress that motivates and enhances performance.'],
#        [0, 19, 4, ..., 5, 4,
#         'Eustress (Positive Stress) - Stress that motivates and enhances performance.']],
#       dtype=object)

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#      Gender  Age  Have you recently experienced stress in your life?  \
# 842       0   19                                                  4
# 841       0   20                                                  5
# 840       1   19                                                  4
# 839       1   19                                                  3
# 838       0   21                                                  3
# ..      ...  ...                                                ...
# 4         0   20                                                  3
# 3         1   20                                                  3
# 2         0   20                                                  5
# 1         0   20                                                  2
# 0         0   20                                                  3
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 842                                                  3
# ...

# %%
df.loc[[2,3],:]
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 2       0   20                                                  5
# 3       1   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 2                                                  4
# 3                                                  4
#
#    Have you been dealing with anxiety or tension recently?  \
# 2                                                  2
# 3                                                  3
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 2                                                  2
# 3                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 2                                                  1
# 3                                                  2
#
#    Have you been getting headaches more often than usual?  \
# ...

# %%
df.loc[[2,3],["Gender","Age"]]
# Out:
#    Gender  Age
# 2       0   20
# 3       1   20

# %%
df.iloc[3,2]
# Out:
# np.int64(3)

# %%
df.drop("Gender",axis=1)
# Out:
#      Age  Have you recently experienced stress in your life?  \
# 0     20                                                  3
# 1     20                                                  2
# 2     20                                                  5
# 3     20                                                  3
# 4     20                                                  3
# ..   ...                                                ...
# 838   21                                                  3
# 839   19                                                  3
# 840   19                                                  4
# 841   20                                                  5
# 842   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# ...
